# %% [markdown]
# <a href="https://colab.research.google.com/github/eshreyareddy/EDA-colab-and-apache-beam-colab/blob/main/Auto_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8166afc0-3e52-498b-a572-6eaf7fdac46e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8166afc0-3e52-498b-a572-6eaf7fdac46e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install sweetviz

import sweetviz as sv

# Create the EDA report using Sweetviz
report = sv.analyze(df_cuisine)
report.show_notebook()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 36.7 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b7e768aa6014> in <cell line: 6>()
#       4
#       5 # Create the EDA report using Sweetviz
# ----> 6 report = sv.analyze(df_cuisine)
#       7 report.show_notebook()
#
# NameError: name 'df_cuisine' is not defined

# %%
import pandas as pd
import sweetviz as sv

# Load the dataset
url = "Cuisine_rating.CSV"
df_cuisine = pd.read_csv(url)

# Create the EDA report using Sweetviz
report = sv.analyze(df_cuisine)
report.show_notebook()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6340ecec1d9c> in <cell line: 6>()
#       4 # Load the dataset
#       5 url = "Cuisine_rating.CSV"
# ----> 6 df_cuisine = pd.read_csv()
#       7
#       8 # Create the EDA report using Sweetviz
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
import sweetviz as sv

# Load the dataset
df_cuisine = pd.read_csv("Cuisine_rating.csv")

# Create the EDA report using Sweetviz
report = sv.analyze(df_cuisine)
report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...
